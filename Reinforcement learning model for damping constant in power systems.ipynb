# %%
# df will be the data provided through simulations
x=df.drop(['amplitude','damping constant'],axis='columns')
y = df['amplitude','damping constant']
# y2= df['damping constant']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dt_amp = DecisionTreeRegressor(random_state=42)
dt_amp.fit(x_train, y_train[0])
y_pred_smp = dt_amp.predict(x_test)
dt_amp.score(y_pred_amp,y_test[0])

#Apply grid search for hyper parameters => verma.

# amp_model = keras.Sequential([
#     keras.layers.Dense(3, input_shape=(6,),activation='relu'),
#     keras.layers.Dense(2, activation='relu'),
#     keras.layers.Dense(1, activation = 'relu')
# ])

# amp_model.compile(optimizer = 'adam', loss='mean_squared_error', metrics=['mean_squared_error'])
# amp_model.fit(x_train,y_train[0],epochs = 100)

# dc_model = keras.Sequential([
#     keras.layers.Dense(3, input_shape=(6,),activation='relu'),
#     keras.layers.Dense(2, activation='relu'),
#     keras.layers.Dense(1, activation = 'relu')
# ])

# dc_model.compile(optimizer = 'adam', loss='mean_squared_error', metrics=['mean_squared_error'])
# dc_model.fit(x_train,y_train[1],epochs = 100)

# %%
# amp_model.evaluate(x_test,y_test[0])
# dc_model.evaluate(x_test,y_test[1])

# %%
from gym import Env
from gym import spaces
import numpy as np

class enviro(Env):
    def __init__(self,sensitivity,penetration,frequency,phase):
        # Observation space consists of T1, T2, D, A, sensitvity,penetration,frequency,phase
        self.observation_space = spaces.Box(low=np.array([0,0, 1, 1,0,0,0,0]), high=np.array([60, 25,10, 10,10000,10000,100,1000]), dtype=np.float32)
        
        # Action space consists of the change in T1 and T2
        self.action_space = spaces.Box(low=np.array([-1, -1]), high=np.array([1, 1]), dtype=np.float32)
        
        # Initialize state variables
        self.T1 = 30
        self.T2 = 5
        self.episode_length = 100
        self.sensitivity = sensitivity
        self.penetration = penetration
        self.frequency = frequency
        self.phase = phase
        self.prev_D = 0
        self.prev_A = 0
        
    def step(self, action):
        # Update T1 and T2 based on action
#         self.T1 = np.clip(self.T1 + action[0], 0, 1)
        self.episode_length = self.episode_length - 1
        self.T1 = self.T1 + action[0]
        if(self.T1<0):
            self.T1 = 0
        elif(self.T1>60):
            self.T1=60
        
        self.T2 = self.T2 + action[1]
        if(self.T2<0):
            self.T2 = 0
        elif(self.T2>25):
            self.T2=25
        
        ip = [self.sensitivity,self.penetration,self.frequency,self.phase,self.T1,self.T2]
        
        # Calculate derived variables
        # D = dc_model.predict(ip)
        # A = amp_model.predict(ip)
        D = (self.T1)*(self.T2)
        A = (100-self.T1)*(100-self.T2)
        # Reward is based on the difference between current and previous values of D and A
        reward = (D - self.prev_D) - 5*(A - self.prev_A)
        
        # Save current values of D and A for the next time step
        self.prev_D = D
        self.prev_A = A
        
        if(self.episode_length<=0):
            done = True
        else:
            done = False
        
        # Information is an empty dictionary
        info = {}
        
        # Return the observation, reward, done, and information
        return np.array([self.T1, self.T2, D, A,self.sensitivity,self.penetration,self.frequency,self.phase]), reward, done, info
    
    def reset(self):
        # Reset T1 and T2 to their initial values
        self.T1 = 30
        self.T2 = 5
      
        # Calculate initial values of D and A
        self.prev_D = 0
        self.prev_A = 0
      
        self.episode_length = 100
      
        # Return the initial observation
        return np.array([self.T1, self.T2, self.prev_D, self.prev_A, self.sensitivity, self.penetration, self.frequency, self.phase])
    
    def state_display(self):
        print("T1 =>",self.T1,"\n")
        print("T2 =>",self.T2,"\n")

# %%
env = enviro()
episodes = 10
for episode in range(1,episodes+1):
    score = 0
    state = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()
        n_state,reward,done,info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
# Out:
# Episode:1 Score:-68.74852343819293
# Episode:2 Score:-325.772513548408
# Episode:3 Score:54.943047341144776
# Episode:4 Score:-150.006860131228
# Episode:5 Score:149.60004736639894
# Episode:6 Score:-974.9924600501384
# Episode:7 Score:336.19862847119043
# Episode:8 Score:465.8564933671187
# Episode:9 Score:-606.9689419576086
# Episode:10 Score:70.22345087887379

# %%
# q learning withhout library
# discount_factor = 0.95
# eps = 0.5
# eps_decay_factor = 0.999
# learning_rate = 0.8
# num_episodes = 500
# q_table = np.zeros([4,2])
# for i in range(num_episodes):
#     state = env.reset()
#     eps *= eps_decay_factor
#     done = False
#     while not done:
#         if np.random.random() < eps or np.sum(q_table[state, :]) == 0:
#             action = np.random.randint(0, 2)
#         else:
#             action = np.argmax(q_table[state, :])
#         new_state, reward, done, _ = env.step(action)
#         q_table[state, action] += reward + learning_rate *(discount_factor * np.max(q_table[new_state, :]) - q_table[state, action])
#         state = new_state
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <cell line: 7>()
#      10 done = False
#      11 while not done:
# ---> 12     if np.random.random() < eps or np.sum(q_table[state, :]) == 0:
#      13         action = np.random.randint(0, env.action_space.n)
#      14     else:
#
# IndexError: index 30 is out of bounds for axis 0 with size 4

# %%
# import stable_baselines3
# from stable_baselines3 import DQN
# # input_new = [0.3,0,1.2,6]
# env= enviro(0.3,0,1.2,6)
# model = DQN('MlpPolicy',env,verbose=1)
# model.learn(total_timesteps=20000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 # input_new = [0.3,0,1.2,6]
#       4 env= enviro(0.3,0,1.2,6)
# ----> 5 model = DQN('MlpPolicy',env,verbose=1)
#       6 model.learn(total_timesteps=20000)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\dqn\dqn.py:98, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      70 def __init__(
#      71     self,
#      72     policy: Union[str, Type[DQNPolicy]],
#    (...)
#      95     _init_setup_model: bool = True,
#      96 ):
# ---> 98     super().__init__(
#      99         policy,
#     100         env,
#     101         learning_rate,
#     102         buffer_size,
#     103         learning_starts,
#     104         batch_size,
#     105         tau,
#     106         gamma,
#     107         train_freq,
#     108         gradient_steps,
#     109         action_noise=None,  # No action noise
#     110         replay_buffer_class=replay_buffer_class,
#     111         replay_buffer_kwargs=replay_buffer_kwargs,
#     112         policy_kwargs=policy_kwargs,
#     113         tensorboard_log=tensorboard_log,
#     114         verbose=verbose,
#     115         device=device,
#     116         seed=seed,
#     117         sde_support=False,
#     118         optimize_memory_usage=optimize_memory_usage,
#     119         supported_action_spaces=(spaces.Discrete,),
#     120         support_multi_env=True,
#     121     )
#     123     self.exploration_initial_eps = exploration_initial_eps
#     124     self.exploration_final_eps = exploration_final_eps
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:106, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      76 def __init__(
#      77     self,
#      78     policy: Union[str, Type[BasePolicy]],
#    (...)
#     103     supported_action_spaces: Optional[Tuple[spaces.Space, ...]] = None,
#     104 ):
# --> 106     super().__init__(
#     107         policy=policy,
#     108         env=env,
#     109         learning_rate=learning_rate,
#     110         policy_kwargs=policy_kwargs,
#     111         tensorboard_log=tensorboard_log,
#     112         verbose=verbose,
#     113         device=device,
#     114         support_multi_env=support_multi_env,
#     115         monitor_wrapper=monitor_wrapper,
#     116         seed=seed,
#     117         use_sde=use_sde,
#     118         sde_sample_freq=sde_sample_freq,
#     119         supported_action_spaces=supported_action_spaces,
#     120     )
#     121     self.buffer_size = buffer_size
#     122     self.batch_size = batch_size
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\base_class.py:168, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     165 self.env = env
#     167 if supported_action_spaces is not None:
# --> 168     assert isinstance(self.action_space, supported_action_spaces), (
#     169         f"The algorithm only supports {supported_action_spaces} as action spaces "
#     170         f"but {self.action_space} was provided"
#     171     )
#     173 if not support_multi_env and self.n_envs > 1:
#     174     raise ValueError(
#     175         "Error: the model does not support multiple envs; it requires " "a single vectorized environment."
#     176     )
#
# AssertionError: The algorithm only supports (<class 'gym.spaces.discrete.Discrete'>,) as action spaces but Box([-1. -1.], [1. 1.], (2,), float32) was provided

# %%
from stable_baselines3 import PPO
env= enviro(0.3,0,1.2,6)
model = PPO('MlpPolicy',env,verbose=1)
model.learn(total_timesteps=20000)          #20000 is a small number btw
# Out:
# C:\Users\Chinmay\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\spaces\box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | -3.32e+04 |
# | time/              |           |
# |    fps             | 674       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -2.98e+04 |
# | time/                   |           |
# |    fps                  | 501       |
# |    iterations           | 2         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0257194 |
# |    clip_fraction        | 0.282     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.83     |
# |    explained_variance   | 8.46e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.64e+06  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.0241   |
# |    std                  | 0.997     |
# |    value_loss           | 1.26e+07  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.61e+04   |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019272316 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.000238    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79e+07    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.99        |
# |    value_loss           | 1.22e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.37e+04   |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013055623 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.00179     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+06    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.983       |
# |    value_loss           | 1.51e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.16e+04   |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012594901 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.00256     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99e+06    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.976       |
# |    value_loss           | 1.54e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.79e+04   |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008958943 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.00294     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+07    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.974       |
# |    value_loss           | 1.88e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.54e+04    |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 7            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0058467668 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.0036       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.05e+06     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00661     |
# |    std                  | 0.968        |
# |    value_loss           | 1.74e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.44e+04    |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060624843 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.00472      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+07     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00557     |
# |    std                  | 0.965        |
# |    value_loss           | 1.82e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 9           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003898338 |
# |    clip_fraction        | 0.00854     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.00546     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+07    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.963       |
# |    value_loss           | 1.76e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.38e+04    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 10           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0024027014 |
# |    clip_fraction        | 0.00322      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.00649      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.12e+06     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.003       |
# |    std                  | 0.962        |
# |    value_loss           | 1.8e+07      |
# ------------------------------------------

# %%
env.state_display()
# Out:
# T1 => 30
#
# T2 => 5
